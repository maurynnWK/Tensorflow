# %%
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from IPython.display import clear_output
from six.moves import urllib
from __future__ import absolute_import,division,print_function,unicode_literals
import tensorflow.compat.v2.feature_column as fc

# %% [markdown]
# ## 1.Linear Regression
# - We are going to use this model to predict survival rate in the titanic dataset

# %%
#load data
train_data=pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
test_data=pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/eval.csv")
y_train=train_data.pop('survived')
y_test=test_data.pop('survived')

# %%
x_train=train_data#train data here has no label column
x_test=test_data#test data here has no label column
x_train
# Out:
#         sex   age  n_siblings_spouses  parch     fare   class     deck  \
# 0      male  22.0                   1      0   7.2500   Third  unknown
# 1    female  38.0                   1      0  71.2833   First        C
# 2    female  26.0                   0      0   7.9250   Third  unknown
# 3    female  35.0                   1      0  53.1000   First        C
# 4      male  28.0                   0      0   8.4583   Third  unknown
# ..      ...   ...                 ...    ...      ...     ...      ...
# 622    male  28.0                   0      0  10.5000  Second  unknown
# 623    male  25.0                   0      0   7.0500   Third  unknown
# 624  female  19.0                   0      0  30.0000   First        B
# 625  female  28.0                   1      2  23.4500   Third  unknown
# 626    male  32.0                   0      0   7.7500   Third  unknown
#
#      embark_town alone
# 0    Southampton     n
# 1      Cherbourg     n
# 2    Southampton     y
# ...

# %%
import tensorflow as tf
import tensorflow as tf
categorical_cols=['sex','n_siblings_spouses','parch','class','deck','embark_town','alone']
numerical_cols=['age','fare']

feature_columns=[]
for feature_name in categorical_cols:
  vocabulary=getattr(train_data,feature_name).unique()#list of uniqua values for each column
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name,vocabulary))

for feature_name in numerical_cols:
    feature_columns.append(tf.feature_column.numeric_column(feature_name,dtype=tf.float32)) 

print(feature_columns)
# Out:
# WARNING:tensorflow:From C:\Users\ADMIN\AppData\Local\Temp\ipykernel_31716\1964182722.py:12: numeric_column (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# ...

# %% [markdown]
# **INPUT FUNCTION**

# %%
def make_input_func(data_df,label_df,num_epochs=10,shuffle=True,batch_size=32):
    def input_function():
        ds=tf.data.Dataset.from_tensor_slices((dict(data_df),label_df))
        if shuffle:
            ds=ds.shuffle(1000)
        ds=ds.batch(batch-size).repeat(num_epochs)
        return ds
    return input_function    
train_input=make_input_func(train_data, y_train)       
test_input=make_input_func(test_data, y_test,num_epochs=1 ,shuffle=False)

# %% [markdown]
# **MODELLING**

# %%
from tensorflow_estimator import estimator
linear_est=estimator.LinearClassifier(feature_columns)

linear_est.train(train_input)
result=linear_est.evaluate(test_input)
print(result['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from tensorflow_estimator import estimator
#       2 linear_est=estimator.LinearClassifier(feature_columns)
#       4 linear_est.train(train_input)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow_estimator\__init__.py:8
#       3 """Public API for tf_estimator._api.v1 namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow_estimator._api.v1 import estimator
#      10 from tensorflow.python.util import module_wrapper as _module_wrapper
#      12 if not isinstance(_sys.modules[__name__], _module_wrapper.TFModuleWrapper):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow_estimator\_api\v1\estimator\__init__.py:8
#       3 """Public API for tf_estimator._api.v1.estimator namespace
#       4 """
#       6 import sys as _sys
# ...
